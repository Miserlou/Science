# %%
import pandas as pd
import glob, os
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
data = pd.DataFrame.from_csv('Data/GSE51081/GSM1237810_T09-1084.PCL', sep='\t', header=0)

# %%
data[:5]
# Out:
#                    GSM1237810_T09-1084.txt_Channel1  \
# GE_BrightCorner_1                          2.179542
# DarkCorner_2                              -0.511203
# DarkCorner_3                              -0.710034
# DarkCorner_4                              -0.659205
# DarkCorner_5                              -0.571706
#
#                    GSM1237810_T09-1084.txt_Channel2
# GE_BrightCorner_1                          1.825372
# DarkCorner_2                              -1.075368
# DarkCorner_3                              -0.861985
# DarkCorner_4                              -0.972789
# DarkCorner_5                              -1.038416

# %%
data = None

# %%
old_data = None
gse = 'GSE51081'
path = os.path.join('Data/', gse + '/')
for pcl_file in os.listdir(path):
    print(pcl_file)
    new_data = pd.DataFrame.from_csv(path + pcl_file, sep='\t', header=0)
    if old_data is not None:
        old_data = pd.concat([old_data, new_data], axis=1)
    else:
        old_data = new_data
# Out:
# GSM1237826_NF1.PCL
# GSM1237819_P005RR.PCL
# GSM1237815_F103.PCL
# GSM1237824_12T206.PCL
# GSM1237810_T09-1084.PCL
# GSM1237821_NF2.PCL
# GSM1237812_S97-PURE.PCL
# GSM1237828_NF3.PCL
# GSM1237817_ITALMAX-PURE.PCL

# %%
data = old_data
data[:5]
# Out:
#                    GSM1237826_NF1.txt_Channel1  GSM1237826_NF1.txt_Channel2  \
# GE_BrightCorner_1                     2.058503                     1.946446
# DarkCorner_2                         -0.651318                    -0.945592
# DarkCorner_3                         -0.677118                    -0.842607
# DarkCorner_4                         -0.645380                    -0.997518
# DarkCorner_5                         -0.764166                    -0.791737
#
#                    GSM1237819_P005RR.txt_Channel1  \
# GE_BrightCorner_1                        2.253895
# DarkCorner_2                            -0.747589
# DarkCorner_3                            -0.747589
# DarkCorner_4                            -0.641019
# DarkCorner_5                            -0.749127
#
#                    GSM1237819_P005RR.txt_Channel2  \
# GE_BrightCorner_1                        2.138278
# DarkCorner_2                            -0.890472
# ...

# %%
corr = data.corr()
corr
# Out:
#                                       GSM1237826_NF1.txt_Channel1  \
# GSM1237826_NF1.txt_Channel1                          1.000000e+00
# GSM1237826_NF1.txt_Channel2                         -2.428807e-16
# GSM1237819_P005RR.txt_Channel1                       9.207322e-01
# GSM1237819_P005RR.txt_Channel2                       4.297758e-02
# GSM1237815_F103.txt_Channel1                         7.447840e-01
# GSM1237815_F103.txt_Channel2                         1.264208e-01
# GSM1237824_12T206.txt_Channel1                       8.729863e-01
# GSM1237824_12T206.txt_Channel2                       5.179574e-02
# GSM1237810_T09-1084.txt_Channel1                     8.509327e-01
# GSM1237810_T09-1084.txt_Channel2                     6.604381e-02
# GSM1237821_NF2.txt_Channel1                          9.003732e-01
# GSM1237821_NF2.txt_Channel2                          3.797356e-02
# GSM1237812_S97-PURE.txt_Channel1                     7.989267e-01
# ...

# %%
plt.matshow(corr)
plt.show()

# %%
corr.style.background_gradient(cmap='viridis')
# Out:
#         <style  type="text/css" >
#
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col0 {
#
#                 background-color:  #fde725;
#
#             }
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col1 {
#
#                 background-color:  #440154;
#
#             }
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col2 {
#
#                 background-color:  #cae11f;
#
#             }
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col3 {
#
#                 background-color:  #471164;
#
#             }
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col4 {
#
#                 background-color:  #5ac864;
#
#             }
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col5 {
#
#                 background-color:  #472d7b;
#
#             }
#
#             #T_9580564a_4402_11e8_8497_0242ac110005row0_col6 {
#
#                 background-color:  #aadc32;
#
#             }
#
# ...

# %%
g = sns.clustermap(corr)
g.savefig(gse + '_cor_matrix.png')

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

principalComponents = pca.fit_transform(data)
principalComponents_notrans = pca.fit(data)

principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

# %%
principalComponents_notrans.components_
# Out:
# array([[-0.15848527, -0.29451078, -0.15854714, -0.29446937, -0.1655658 ,
#         -0.2902714 , -0.16434743, -0.29030739, -0.16478042, -0.29063778,
#         -0.16462613, -0.29107639, -0.1399797 , -0.30338533, -0.15524469,
#         -0.29625498, -0.12570607, -0.3009674 ],
#        [ 0.3131942 , -0.1680302 ,  0.30824142, -0.16482304,  0.24964827,
#         -0.14049615,  0.29496961, -0.16290758,  0.29623652, -0.16690925,
#          0.29787514, -0.16710705,  0.28935074, -0.12858229,  0.30194388,
#         -0.15733676,  0.29663349, -0.13944059]])

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title(gse + '2 component PCA', fontsize = 20)

ax.scatter(principalComponents_notrans.components_[0, :], principalComponents_notrans.components_[1, :])
ax.axis('equal');
fig.savefig(gse + '_cor_PCA.png')
